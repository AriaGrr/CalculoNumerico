# %% [markdown]
# # PROJETO

# %% [markdown]
# O arquivo escolhido foi:
#
# dados_ban.csvs2.png)

# %% [markdown]
# Colunas:
#
# ![Captura de tela 2024-11-14 130122.png](attachment:9fbc9eea-9197-429d-8076-225e9c928207.png)

# %% [markdown]
# ## a)	Fazer cinco regressões lineares mudando a variável dependente (y) e a variável independente(x). Para cada regressão apresentar o gráfico de dispersão, a reta ajustada, o coeficiente de correlação de Pearson e o coeficiente de determinação(R2).
#
# Usando:
#
# ![Captura de tela 2024-11-14 130410.png](attachment:83347ca0-8680-4d55-bee9-6c22a157fe8b.png)

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.metrics import mean_squared_error, r2_score
# from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# Carregar os dados
data = pd.read_csv('dados_banco.csv', header=(0))

# Converter para NumPy array
data = data.to_numpy()

# Variaveis
# Y 
saldocc = data[:,7]
# Y 
devedorcartao = data[:,9]
# Y 
inadimplente = data[:,10]
# X e Y 
salario = data[:,5]
# X 
saldopoupanca = data[:,6]
# X 
idade = data[:,3]

# Montando
# X
Xsalario = np.array(salario).reshape(-1, 1)
Xsaldopoupanca = np.array(saldopoupanca).reshape(-1, 1)
Xidade = np.array(idade).reshape(-1, 1)
# Y
Ysaldocc = np.array(saldocc)
Ydevedorcartao = np.array(devedorcartao)
Yinadimplente = np.array(inadimplente)
Ysalario = np.array(salario)

# | Independente (X) | Dependente (Y) |
# | idade | salario |
# | saldopoupanca | saldocc |
# | salario | devedorcartao |
# | idade | devedorcartao |
# | salario | inadimplente |

# Regressão Linear fit X e Y
modelo1 = LinearRegression().fit(Xidade, Ysalario)
modelo2 = LinearRegression().fit(Xsaldopoupanca, Ysaldocc)
modelo3 = LinearRegression().fit(Xsalario, Ydevedorcartao)
modelo4 = LinearRegression().fit(Xidade, Ydevedorcartao)
modelo5 = LinearRegression().fit(Xsalario, Yinadimplente)

# Print dos modelos
print("Modelos: Intercepto e Coeficiente\n")
print("Modelo 1: Idade e Salario")
# print(modelo1)
print("Intercepto:", modelo1.intercept_)
print("Coeficiente:", modelo1.coef_)
# print(modelo1.intercept_)
# print (modelo1.coef_)
print("\n")
      
print("Modelo 2: Saldo Poupança e Saldo CC")
# print(modelo2)
print("Intercepto:", modelo2.intercept_)
print("Coeficiente:", modelo2.coef_)
# print(modelo2.intercept_)
# print (modelo2.coef_)
print("\n")
      
print("Modelo 3: Salario e Devedor Cartão")
# print(modelo3)
print("Intercepto:", modelo3.intercept_)
print("Coeficiente:", modelo3.coef_)
# print(modelo3.intercept_)
# print (modelo3.coef_)
print("\n")
      
print("Modelo 4: Idade e Devedor Cartão")
# print(modelo4)
print("Intercepto:", modelo4.intercept_)
print("Coeficiente:", modelo4.coef_)
# print(modelo4.intercept_)
# print (modelo4.coef_)
print("\n")
      
print("Modelo 5: Salario e Inadimplente")
# print(modelo5)
print("Intercepto:", modelo5.intercept_)
print("Coeficiente:", modelo5.coef_)
# print(modelo5.intercept_)
# print (modelo5.coef_)
# print("\n")

# Previsão
# Y
Ysalario_pred = modelo1.predict(Xidade)
Ysaldocc_pred = modelo2.predict(Xsaldopoupanca)
Ydevedorcartao_pred = modelo3.predict(Xsalario)
Ydevedorcartao_pred2 = modelo4.predict(Xidade)
Yinadimplente_pred = modelo5.predict(Xsalario)

# # EXEMPLO NUNO
# # Mostrar os dados
# plt.scatter(x, y, color = "b", marker = "o", s = 50) 
# # Mostrar a reta de regressão
# plt.plot(x, y_pred, color = "r") 
# plt.xlabel('x', fontsize = 15) 
# plt.ylabel('y', fontsize = 15) 
# plt.show(True) 
# plt.scatter(X, Y)
# plt.plot(X, modelo.predict(X), color = 'red')
# Out:
# Modelos: Intercepto e Coeficiente
#
# Modelo 1: Idade e Salario
# Intercepto: 1849.4729277100164
# Coeficiente: [114.25126519]
#
#
# Modelo 2: Saldo Poupança e Saldo CC
# Intercepto: 132.1982745482601
# Coeficiente: [2.70520667]
#
#
# Modelo 3: Salario e Devedor Cartão
# Intercepto: 2062.138635209952
# Coeficiente: [0.12312363]
#
#
# Modelo 4: Idade e Devedor Cartão
# Intercepto: 1293.0686880840199
# Coeficiente: [45.41055858]
#
#
# Modelo 5: Salario e Inadimplente
# Intercepto: 1.093295784589344
# Coeficiente: [-0.00015452]

# %% [markdown]
# ## PLOTS

# %%
# Plot
# X e Y
plt.scatter(Xidade, Ysalario, color='black')
plt.plot(Xidade, Ysalario_pred, color='blue', linewidth=3)
plt.xlabel('Idade')
plt.ylabel('Salario')
plt.show()

# Segundo plot

plt.scatter(Xidade, Ysalario)
plt.plot(Xidade, modelo1.predict(Xidade), color = 'red')

# %%
# X e Y
plt.scatter(Xsaldopoupanca, Ysaldocc, color='black')
plt.plot(Xsaldopoupanca, Ysaldocc_pred, color='blue', linewidth=3)
plt.xlabel('Saldo Poupança')
plt.ylabel('Saldo CC')
plt.show()

# Segundo plot

plt.scatter(Xsaldopoupanca, Ysaldocc)
plt.plot(Xsaldopoupanca, modelo2.predict(Xsaldopoupanca), color = 'red')

# %%
# X e Y
plt.scatter(Xsalario, Ydevedorcartao, color='black')
plt.plot(Xsalario, Ydevedorcartao_pred, color='blue', linewidth=3)
plt.xlabel('Salario')
plt.ylabel('Devedor Cartão')
plt.show()

# Segundo plot

plt.scatter(Xsalario, Ydevedorcartao)
plt.plot(Xsalario, modelo3.predict(Xsalario), color = 'red')

# %%
# X e Y
plt.scatter(Xidade, Ydevedorcartao, color='black')
plt.plot(Xidade, Ydevedorcartao_pred2, color='blue', linewidth=3)
plt.xlabel('Idade')
plt.ylabel('Devedor Cartão')
plt.show()

# Segundo plot

plt.scatter(Xidade, Ydevedorcartao)
plt.plot(Xidade, modelo4.predict(Xidade), color = 'red')

# %%
# X e Y
plt.scatter(Xsalario, Yinadimplente, color='black')
plt.plot(Xsalario, Yinadimplente_pred, color='blue', linewidth=3)
plt.xlabel('Salario')
plt.ylabel('Inadimplente')
plt.show()

# Segundo plot

plt.scatter(Xsalario, Yinadimplente)
plt.plot(Xsalario, modelo5.predict(Xsalario), color = 'red')

# %% [markdown]
# ## R2

# %%
# R2
# X e Y
print('R2 Idade e Salario:\n', r2_score(Ysalario, Ysalario_pred))
print("\n")

# X e Y
print('R2 Saldo Poupança e Saldo CC:\n', r2_score(Ysaldocc, Ysaldocc_pred))
print("\n")

# X e Y
print('R2 Salario e Devedor Cartão:\n', r2_score(Ydevedorcartao, Ydevedorcartao_pred))
print("\n")

# X e Y
print('R2 Idade e Devedor Cartão:\n', r2_score(Ydevedorcartao, Ydevedorcartao_pred2))
print("\n")

# X e Y
print('R2 Salario e Inadimplente:\n', r2_score(Yinadimplente, Yinadimplente_pred))
# Out:
# R2 Idade e Salario:
#  0.723632784064704
#
#
# R2 Saldo Poupança e Saldo CC:
#  0.013886277492711208
#
#
# R2 Salario e Devedor Cartão:
#  0.0005906858621302913
#
#
# R2 Idade e Devedor Cartão:
#  0.004454343127712201
#
#
# R2 Salario e Inadimplente:
#  0.019952041226995232

# %%
# print(Ysalario.shape)
# Para verificar se possuem o mesmo shape
# print(Ysalario.dtype)
# Se o dtype for object, significa que é uma mistura de tipos
# Para evitar bugs no corrcoef devemos converter para um único tipo

# Converter todos para float para evitar bugs
# X
Xsalario = Xsalario.astype(np.float64)
Xsaldopoupanca = Xsaldopoupanca.astype(np.float64)
Xidade = Xidade.astype(np.float64)
# Y
Ysalario = Ysalario.astype(np.float64)
Ysaldocc = Ysaldocc.astype(np.float64)
Ydevedorcartao = Ydevedorcartao.astype(np.float64)
Yinadimplente = Yinadimplente.astype(np.float64)

# print(Xidade)
# print(Xsalario)
# print(Xsaldopoupanca)

# print(Ysaldocc)
# print(Ydevedorcartao)
# print(Yinadimplente)
# print(Ysalario)

# %% [markdown]
# ## COEFICIENTES DE CORRELAÇÃO DE PEARSON

# %%
print('Coeficiente de correlação Idade e Salario: \n')

# print(np.corrcoef(Xidade, Ysalario))
# print("\n")
# print(np.corrcoef(Xidade.T, Ysalario.T)[0, 1])
# print("\n")
# print(np.corrcoef(Xidade.flatten(), Ysalario.flatten()))
print(np.corrcoef(Xidade.T, Ysalario.T))
print("\n")

print('Coeficiente de correlação Saldo Poupança e Saldo CC: \n')
print(np.corrcoef(Xsaldopoupanca.T, Ysaldocc.T))
print("\n")

print('Coeficiente de correlação Salario e Devedor Cartão: \n')
print(np.corrcoef(Xsalario.T, Ydevedorcartao.T))
print("\n")

print('Coeficiente de correlação Idade e Devedor Cartão: \n')
print(np.corrcoef(Xidade.T, Ydevedorcartao.T))
print("\n")

print('Coeficiente de correlação Salario e Inadimplente: \n')
print(np.corrcoef(Xsalario.T, Yinadimplente.T))
# Out:
# Coeficiente de correlação Idade e Salario:
#
# [[1.         0.85066608]
#  [0.85066608 1.        ]]
#
#
# Coeficiente de correlação Saldo Poupança e Saldo CC:
#
# [[1.         0.11784005]
#  [0.11784005 1.        ]]
#
#
# Coeficiente de correlação Salario e Devedor Cartão:
#
# [[1.         0.02430403]
#  [0.02430403 1.        ]]
#
#
# Coeficiente de correlação Idade e Devedor Cartão:
#
# [[1.         0.06674087]
#  [0.06674087 1.        ]]
#
#
# Coeficiente de correlação Salario e Inadimplente:
#
# [[ 1.         -0.14125169]
#  [-0.14125169  1.        ]]

# %% [markdown]
# ## b)	Fazer uma regressão linear múltipla utilizando no mínimo quatro variáveis independentes (x). Apresentar os resultados para o coeficiente de determinação(R2) e os coeficientes da regressão sm.ols  e verificar quais variáveis dependentes devem ser descartadas analisando o p-valor. Após descartar a variável menos significativa refazer a regressão novamente.

# %%
import pandas as pd
import statsmodels.formula.api as sm
df = pd.read_csv('dados_banco.csv', header=(0))
# Eliminar o ponto no nome das columas para usar o sm.ols
# Substituindo o _ por nada 
df.columns = [ x.replace('_','') for x in df.columns ]
# Trocando letras para facilitar escrita 
df.columns = [x.replace('ç', 'c') for x in df.columns]
# Usando saldo_investimento como variavel dependente, enquanto usamos o salario, a idade, o saldo na conta corrente e o saldo na poupança como termos independentes. 
model = sm.ols(formula="Saldoinvestimento ~ Salario+Saldocc+Saldopoupanca + Idade ", data=df)
result = model.fit()
print(result.summary())
# Como o valor p de salario foi o maior entre todos os termos, ele foi retirado e a tabela foi refeita sem ele .
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      Saldoinvestimento   R-squared:                       0.922
# Model:                            OLS   Adj. R-squared:                  0.922
# Method:                 Least Squares   F-statistic:                 2.960e+04
# Date:                Thu, 14 Nov 2024   Prob (F-statistic):               0.00
# Time:                        17:27:46   Log-Likelihood:                -84162.
# No. Observations:               10000   AIC:                         1.683e+05
# Df Residuals:                    9995   BIC:                         1.684e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept       -77.8582    164.553     -0.473      0.636    -400.415     244.698
# Salario          -0.0261      0.057     -0.458      0.647      -0.138       0.086
# Saldocc          -0.0427      0.053     -0.809      0.418      -0.146       0.061
# Saldopoupanca     0.6642      0.002    341.733      0.000       0.660       0.668
# Idade             7.9768      7.127      1.119      0.263      -5.994      21.948
# ==============================================================================
# Omnibus:                     2579.652   Durbin-Watson:                   2.032
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           198002.106
# Skew:                           0.174   Prob(JB):                         0.00
# Kurtosis:                      24.796   Cond. No.                     1.03e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.03e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#b) segunda parte 

import pandas as pd
import statsmodels.formula.api as sm
df = pd.read_csv('dados_banco.csv', header=(0))
# Eliminar o ponto no nome das columas para usar o sm.ols
# Substituindo o _ por nada 
df.columns = [ x.replace('_','') for x in df.columns ]
# Trocando letras para facilitar escrita 
df.columns = [x.replace('ç', 'c') for x in df.columns]
# Nova regressão com apenas saldo da conta corrente, saldo de poupança e idade sendo usados. 
model = sm.ols(formula="Saldoinvestimento ~ Saldocc+Salario + Idade ", data=df)
result = model.fit()
print(result.summary())
# Após isso, foi refeito a tabela sem o uso do solário dentro dos termos independentes.
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      Saldoinvestimento   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     42.96
# Date:                Thu, 14 Nov 2024   Prob (F-statistic):           1.42e-27
# Time:                        17:46:02   Log-Likelihood:                -96863.
# No. Observations:               10000   AIC:                         1.937e+05
# Df Residuals:                    9996   BIC:                         1.938e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -804.3222    585.969     -1.373      0.170   -1952.940     344.296
# Saldocc        1.6097      0.187      8.595      0.000       1.243       1.977
# Salario        0.3108      0.203      1.528      0.127      -0.088       0.710
# Idade        -20.9959     25.381     -0.827      0.408     -70.747      28.755
# ==============================================================================
# Omnibus:                     4734.872   Durbin-Watson:                   1.993
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            19349.040
# Skew:                           2.445   Prob(JB):                         0.00
# Kurtosis:                       7.746   Cond. No.                     8.35e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.35e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
